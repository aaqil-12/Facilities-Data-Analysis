# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
case_df = pd.read_csv("/Users/aadilsheriff/Downloads/archive/Cases against Police Personnels/2016 Cases against Police Personnels.csv")

# %%
case_df
# Out:
#     S. No. Category           State/UT  \
# 0        1    State     Andhra Pradesh
# 1        2    State  Arunachal Pradesh
# 2        3    State              Assam
# 3        4    State              Bihar
# 4        5    State       Chhattisgarh
# 5        6    State                Goa
# 6        7    State            Gujarat
# 7        8    State            Haryana
# 8        9    State   Himachal Pradesh
# 9       10    State    Jammu & Kashmir
# 10      11    State          Jharkhand
# 11      12    State          Karnataka
# 12      13    State             Kerala
# 13      14    State     Madhya Pradesh
# 14      15    State        Maharashtra
# 15      16    State            Manipur
# 16      17    State          Meghalaya
# 17      18    State            Mizoram
# 18      19    State           Nagaland
# 19      20    State             Odisha
# 20      21    State             Punjab
# 21      22    State          Rajasthan
# 22      23    State             Sikkim
# ...

# %%
case_df.shape
# Out:
# (36, 11)

# %%
case_null= case_df.isna().sum()

# %%
case_null
# Out:
# S. No.                                                       0
# Category                                                     0
# State/UT                                                     0
# Total Number of Criminal Cases Registered during the year    0
# Police Personnel Arrested                                    0
# Cases Chargesheeted                                          0
# Police Personnel Chargesheeted                               0
# Police Personnel whose Cases were withdrawn/ Disposed Off    0
# Police Personnel whose Trials were Completed                 0
# Police Personnel Convicted                                   0
# Police Personnel Acquitted                                   0
# dtype: int64

# %%
case_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 11 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   S. No.                                                     36 non-null     int64
#  1   Category                                                   36 non-null     object
#  2   State/UT                                                   36 non-null     object
#  3   Total Number of Criminal Cases Registered during the year  36 non-null     int64
#  4   Police Personnel Arrested                                  36 non-null     int64
#  5   Cases Chargesheeted                                        36 non-null     int64
#  6   Police Personnel Chargesheeted                             36 non-null     int64
#  7   Police Personnel whose Cases were withdrawn/ Disposed Off  36 non-null     int64
# ...

# %%
case_df['Category'] = case_df['Category'].astype('string')
case_df['State/UT'] = case_df['State/UT'].astype('string')

# %%
case_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 11 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   S. No.                                                     36 non-null     int64
#  1   Category                                                   36 non-null     string
#  2   State/UT                                                   36 non-null     string
#  3   Total Number of Criminal Cases Registered during the year  36 non-null     int64
#  4   Police Personnel Arrested                                  36 non-null     int64
#  5   Cases Chargesheeted                                        36 non-null     int64
#  6   Police Personnel Chargesheeted                             36 non-null     int64
#  7   Police Personnel whose Cases were withdrawn/ Disposed Off  36 non-null     int64
# ...

# %%
case_df.head()
# Out:
#    S. No. Category           State/UT  \
# 0       1    State     Andhra Pradesh
# 1       2    State  Arunachal Pradesh
# 2       3    State              Assam
# 3       4    State              Bihar
# 4       5    State       Chhattisgarh
#
#    Total Number of Criminal Cases Registered during the year  \
# 0                                                100
# 1                                                 24
# 2                                                 37
# 3                                                 43
# 4                                                 65
#
#    Police Personnel Arrested  Cases Chargesheeted  \
# 0                         36                   28
# 1                         10                   13
# 2                         18                    8
# 3                          0                   40
# 4                         26                   32
#
#    Police Personnel Chargesheeted  \
# 0                              29
# ...

# %%
case_df.tail()
# Out:
#     S. No. Category     State/UT  \
# 31      32       UT   D&N Haveli
# 32      33       UT  Daman & Diu
# 33      34       UT        Delhi
# 34      35       UT  Lakshadweep
# 35      36       UT   Puducherry
#
#     Total Number of Criminal Cases Registered during the year  \
# 31                                                  0
# 32                                                  1
# 33                                                136
# 34                                                  0
# 35                                                 96
#
#     Police Personnel Arrested  Cases Chargesheeted  \
# 31                          0                    0
# 32                          5                    0
# 33                         42                    2
# 34                          0                    0
# 35                          0                   96
#
#     Police Personnel Chargesheeted  \
# 31                               0
# ...

# %%
case_df=case_df.set_axis(['S.NO', 'Category', 'State', 'Criminal_cases', 'Arrested','Case_Chargesheet','Personnel_chargesheet','Withdrawn/Disposed_off','Trails_completed','Convicted','Acquitted'] ,axis=1)

# %%
case_df
# Out:
#     S.NO Category              State  Criminal_cases  Arrested  \
# 0      1    State     Andhra Pradesh             100        36
# 1      2    State  Arunachal Pradesh              24        10
# 2      3    State              Assam              37        18
# 3      4    State              Bihar              43         0
# 4      5    State       Chhattisgarh              65        26
# 5      6    State                Goa              20        11
# 6      7    State            Gujarat             130       131
# 7      8    State            Haryana              34        41
# 8      9    State   Himachal Pradesh              11         7
# 9     10    State    Jammu & Kashmir              29        22
# 10    11    State          Jharkhand               3         2
# 11    12    State          Karnataka              63        23
# 12    13    State             Kerala             171        50
# 13    14    State     Madhya Pradesh              66        44
# ...

# %%
case_sort= case_df.sort_values('State')
case_sort= case_df.sort_values('Criminal_cases')
case_sort= case_df.sort_values('Arrested')
case_sort= case_df.sort_values('Case_Chargesheet')

# %%
case_sort= case_df.sort_values('Withdrawn/Disposed_off')
case_sort= case_df.sort_values('Trails_completed')
case_sort= case_df.sort_values('Convicted')
case_sort= case_df.sort_values('Acquitted')

# %%
case_df.drop_duplicates(keep=False)
# Out:
#     S.NO Category              State  Criminal_cases  Arrested  \
# 0      1    State     Andhra Pradesh             100        36
# 1      2    State  Arunachal Pradesh              24        10
# 2      3    State              Assam              37        18
# 3      4    State              Bihar              43         0
# 4      5    State       Chhattisgarh              65        26
# 5      6    State                Goa              20        11
# 6      7    State            Gujarat             130       131
# 7      8    State            Haryana              34        41
# 8      9    State   Himachal Pradesh              11         7
# 9     10    State    Jammu & Kashmir              29        22
# 10    11    State          Jharkhand               3         2
# 11    12    State          Karnataka              63        23
# 12    13    State             Kerala             171        50
# 13    14    State     Madhya Pradesh              66        44
# ...

# %%
case_df.drop_duplicates(subset=['State'])
case_df.drop_duplicates(subset=['Criminal_cases'])
case_df.drop_duplicates(subset=['Arrested'])
case_df.drop_duplicates(subset=['Case_Chargesheet'])
case_df.drop_duplicates(subset=['Trails_completed'])
case_df.drop_duplicates(subset=['Convicted'])
case_df.drop_duplicates(subset=['Acquitted'])
# Out:
#     S.NO Category              State  Criminal_cases  Arrested  \
# 0      1    State     Andhra Pradesh             100        36
# 1      2    State  Arunachal Pradesh              24        10
# 2      3    State              Assam              37        18
# 6      7    State            Gujarat             130       131
# 14    15    State        Maharashtra             487       388
# 20    21    State             Punjab              88        70
# 26    27    State      Uttar Pradesh             315       187
#
#     Case_Chargesheet  Personnel_chargesheet  Withdrawn/Disposed_off  \
# 0                 28                     29                       5
# 1                 13                     13                       0
# 2                  8                      8                       1
# 6                 91                    105                       2
# 14               196                    209                      37
# ...

# %%
case_df
# Out:
#     S.NO Category              State  Criminal_cases  Arrested  \
# 0      1    State     Andhra Pradesh             100        36
# 1      2    State  Arunachal Pradesh              24        10
# 2      3    State              Assam              37        18
# 3      4    State              Bihar              43         0
# 4      5    State       Chhattisgarh              65        26
# 5      6    State                Goa              20        11
# 6      7    State            Gujarat             130       131
# 7      8    State            Haryana              34        41
# 8      9    State   Himachal Pradesh              11         7
# 9     10    State    Jammu & Kashmir              29        22
# 10    11    State          Jharkhand               3         2
# 11    12    State          Karnataka              63        23
# 12    13    State             Kerala             171        50
# 13    14    State     Madhya Pradesh              66        44
# ...

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(x=case_df.State, y=case_df.Criminal_cases)

plt.title("year vs Year ");
plt.xlabel('Type',labelpad=00) 
plt.xticks(rotation=90, ha='right')

sns.set(rc = {'figure.figsize':(200,400)})

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
sns.barplot(case_df.State, case_df.Arrested);
# Out:
# /Users/aadilsheriff/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
sns.barplot(case_df.State, case_df.Case_Chargesheet);
# Out:
# /Users/aadilsheriff/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=case_df.State, y=case_df.Personnel_chargesheet)
plt.xticks(rotation=75)

plt.title("State vs total");
plt.xlabel('Total',labelpad=100) 
sns.set(rc = {'figure.figsize':(700,600)})

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=case_df.State, y=case_df.Trails_completed)

plt.title("Gender vs Total ");
plt.xticks(rotation=75)


plt.xlabel('Gender',labelpad=100) 
sns.set(rc = {'figure.figsize':(200,400)})

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
sns.barplot(case_df.State, case_df.Convicted);
# Out:
# /Users/aadilsheriff/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=case_df.State, y=case_df.Acquitted)
plt.xticks(rotation=75)

plt.title("State vs total");
plt.xlabel('Total',labelpad=100) 
sns.set(rc = {'figure.figsize':(700,600)})

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
sns.barplot(case_df.Criminal_cases	, case_df.Personnel_chargesheet	)
# Out:
# /Users/aadilsheriff/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Criminal_cases', ylabel='Personnel_chargesheet'>

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(x=case_df.Arrested, y=case_df.Convicted)
plt.title("year vs Year ");
plt.xlabel('Type',labelpad=00) 
plt.xticks(rotation=90, ha='right')

sns.set(rc = {'figure.figsize':(200,400)})

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
sns.barplot(case_df.Convicted	, case_df.Acquitted	)
# Out:
# /Users/aadilsheriff/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Convicted', ylabel='Acquitted'>
